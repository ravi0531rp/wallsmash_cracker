# %%
import numpy as np
import cv2
import time
import os
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as ssim
from glob import glob

# %%
im_1 = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/1.jpg")
gray = cv2.cvtColor(im_1, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
ret, thresh1 = cv2.threshold(gray, 245, 255, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %%
im_2 = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/2.jpg")
gray = cv2.cvtColor(im_2, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
ret, thresh1 = cv2.threshold(gray, 245, 255, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %%
im_3 = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/3.jpg")
gray = cv2.cvtColor(im_3, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
ret, thresh1 = cv2.threshold(gray, 245, 255, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %%
im_4 = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/4.jpg")
gray = cv2.cvtColor(im_4, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
ret, thresh1 = cv2.threshold(gray, 245, 255, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %%
im_5 = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/5.jpg")
gray = cv2.cvtColor(im_5, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
ret, thresh1 = cv2.threshold(gray, 245, 255, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %%
im_6 = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/6.jpg")
gray = cv2.cvtColor(im_6, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
ret, thresh1 = cv2.threshold(gray, 245, 255, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[68], line 2
#       1 im_6 = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/6.jpg")
# ----> 2 gray = cv2.cvtColor(im_6, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
#       3 ret, thresh1 = cv2.threshold(gray, 245, 255, cv2.THRESH_BINARY)
#       4 plt.imshow(thresh1, cmap='gray')
#
# error: OpenCV(4.5.4) /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
im_7 = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/7.jpg")
gray = cv2.cvtColor(im_7, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
ret, thresh1 = cv2.threshold(gray, 245, 255, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %%
im_8 = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/8.jpg")
gray = cv2.cvtColor(im_8, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
ret, thresh1 = cv2.threshold(gray, 245, 255, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %%
im_9 = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/9.jpg")
gray_9 = cv2.cvtColor(im_9, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
ret, thresh9 = cv2.threshold(gray_9, 245, 255, cv2.THRESH_BINARY)
plt.imshow(thresh9, cmap='gray')

# %%
im_black = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/black.jpg")
gray = cv2.cvtColor(im_black, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
ret, thresh1 = cv2.threshold(gray, 50, 255, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %%
im_ball = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/ball.jpg")
gray_ball = cv2.cvtColor(im_ball, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
ret, thresh1 = cv2.threshold(gray_ball, 50, 255, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %%
im_position = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/references/position.jpg")
gray_pos = cv2.cvtColor(im_position, cv2.COLOR_BGR2GRAY)[50:100, 150:220]
ret, thresh1 = cv2.threshold(gray_pos, 20, 255, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %%
ssim(gray_pos, gray_ball)
# Out:
# 0.7622326787706527

# %%
import easyocr
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
files = glob("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/*.jpg")

# %%
for f in files:
    text = reader.readtext(f)
    if text != []:
        print(text)
        print(f)
# Out:
# [([[157, 55], [207, 55], [207, 97], [157, 97]], '10', 0.9995963413511699)]
# /Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/patch_02.jpg
# [([[155, 55], [207, 55], [207, 97], [155, 97]], '10', 0.9951147209206971)]
# /Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/patch_00.jpg
# [([[157, 55], [207, 55], [207, 97], [157, 97]], '10', 0.6263672467135913)]
# /Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/patch_04.jpg
# [([[161, 57], [209, 57], [209, 97], [161, 97]], '10', 0.8447206948476523)]
# /Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/patch_06.jpg

# %%
from paddleocr import PaddleOCR,draw_ocr

# %%
files = glob("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/*.jpg")
ocr = PaddleOCR(use_angle_cls=True, lang='en') 
results = {}
for f in files:
    result = ocr.ocr(f, cls=True)
    if result != [[]]:
        result = np.array(result).squeeze()[1][0]
        results[f] = result

vals = list(results.values())
print(set(vals))
# Out:
# [2023/01/06 01:55:00] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/raprak-blrm20/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/raprak-blrm20/.paddleocr/whl/rec/en/en_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='en') 
img_path = "../images/boxes7/patch_01.jpg"
result = ocr.ocr(img_path, cls=True)
# result = np.array(result).squeeze()[1][0]
# Out:
# [2023/01/06 01:52:33] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/raprak-blrm20/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/raprak-blrm20/.paddleocr/whl/rec/en/en_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
results
# Out:
# {'/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/patch_60.jpg': '0',
#  '/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/patch_75.jpg': '2',
#  '/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/patch_61.jpg': '5',
#  '/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/patch_88.jpg': '5',
#  '/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/patch_77.jpg': '5',
#  '/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/patch_63.jpg': '5',
#  '/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/patch_62.jpg': '2',
#  '/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes7/patch_73.jpg': '2',
# ...

# %%
len(results)
# Out:
# 30

# %%
vals = list(results.values())
print(set(vals))

# %%
# Out:
# {'0', '10', '2', '4', '5', '6', '7', '8'}

# %%
from skimage.metrics import structural_similarity as ssim

# %%
import cv2

# %%
im1 = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes8/patch_00.jpg",0)
im2 = cv2.imread("/Users/raprak-blrm20/Desktop/personal/CODES/m-projects/a-games/wallsmash_cracker/images/boxes8/patch_00.jpg",0)

# %%
ssim(im1,im2)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt

# %%
refer_4 = cv2.imread("../images/references/4.jpg", 0)[52:102, 144:214]
_, thresh1 = cv2.threshold(refer_4, 245, 255, cv2.THRESH_BINARY)

im = cv2.imread("../images/boxes8/patch_20.jpg", 0)[52:102, 144:214]
_, thresh2 = cv2.threshold(im, 245, 255, cv2.THRESH_BINARY)

refer_1 = cv2.imread("../images/references/1.jpg", 0)[52:102, 144:214]
_, thresh3 = cv2.threshold(refer_1, 245, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(thresh1, cmap='gray')

# %%
plt.imshow(thresh2, cmap='gray')

# %%
ssim(thresh1, thresh2)
# Out:
# 0.7484181427565388

# %%
ssim(thresh2, thresh3)
# Out:
# 0.7829729478918076

# %%
im = cv2.imread("../images/boxes8/patch_20.jpg", 0)
_, thresh2 = cv2.threshold(im, 245, 255, cv2.THRESH_BINARY)
plt.imshow(thresh2, cmap='gray')

# %%
thresh2.shape
# Out:
# (154, 358)

# %%
center = (77, 179)

# %%
# 50 , 70
# 25 , 35

plt.imshow(thresh2[52:102, 144:214], cmap='gray')
